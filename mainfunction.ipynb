# %% [markdown]
# <a href="https://colab.research.google.com/github/MohammedBaz/VoilaImageClassifierh5/blob/main/mainfunction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import ipywidgets as widgets
uploader = widgets.FileUpload()
uploader
# Out:
# FileUpload(value={}, description='Upload')

# %%
import io
from PIL import Image,ImageOps
for name, file_info in uploader.value.items():
  img = Image.open(io.BytesIO(file_info['content']))
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=469x339 at 0x7F88D6968AD0>

# %%
# !pip install keras
import numpy as np 
import keras 

model = keras.models.load_model("model.h5")
size = (299, 299) #define the size of the image
 

ximg = ImageOps.fit(img, size, Image.ANTIALIAS) #use ImageOps to fit the image into the size that suit the model.
ximg = ImageOps.grayscale(ximg)         #convert the given image into grayscale
ximg = np.asarray(ximg)                 #convert image into array 
ximg =ximg.reshape(1,299,299,1)         #rescale it into the shape expected by model.predict() before calling it 
prediction = model.predict(ximg)
print(prediction)
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (2.6.0)
# [[2.2473817e-13]]
